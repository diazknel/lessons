# %%
DIGIT_MAP = {
    'zero':  '0',
    'one':   '1',
    'two':   '2',
    'three': '3',
    'four':  '4',
    'five':  '5',
    'six':   '6',
    'seven': '7',
    'eight': '8',
    'nine':  '9',
}


def convert1(s):
    number = ''
    for token in s:
        number += DIGIT_MAP[token]
    x = int(number)
    return x

def convert2(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
        print(f"Conversion succeeded! x = {x}")
    except KeyError:
        print("Conversion failed K!")
        x = -1
    except TypeError:
        print("Conversion failed T!")
        x = -2
    print(x)
    

def convert3(s):
    """Convert a string to an integer."""
    x = -1
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
        print(f"Conversion succeeded! x = {x}")
    except (KeyError, TypeError):
        print("Conversion failed!")
    return x    
    
def convert4(s):
    """Convert a string to an integer."""
    x = -1
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
    except (KeyError, TypeError):
        pass
    return x

    
def convert6(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        return int(number)
    except (KeyError, TypeError) as e:
        print(f"Conversion error: {e!r}",
              file=sys.stderr)
        return -1

def convert7(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        return int(number)
    except (KeyError, TypeError) as e:
        print(f"Conversion error: {e!r}",
              file=sys.stderr)
        raise 
    

def string_log(s):
    v = convert7(s)
    return log(v)

convert("one six seven".split())

convert("one grax seven".split())

convert(512)
# Out:
# Conversion error: KeyError('grax')
# Conversion error: TypeError("'int' object is not iterable")
# -1

# %%
DIGIT_MAP = {
    'zero':  '0',
    'one':   '1',
    'two':   '2',
    'three': '3',
    'four':  '4',
    'five':  '5',
    'six':   '6',
    'seven': '7',
    'eight': '8',
    'nine':  '9',
}


def convert(s):
    number = ''
    for token in s:
        number += DIGIT_MAP[token]
    x = int(number)
    return x

def convert2(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
        print(f"Conversion succeeded! x = {x}")
    except KeyError:
        print("Conversion failed!")
        x = -1
    return x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cz/0wfwkq6s5k1c7m5_4xbzy9z00000gn/T/ipykernel_3343/2945578198.py in <module>
#      34 convert("one six seven".split())
#      35
# ---> 36 convert("one grax seven".split())
#      37
#      38 convert(512)
#
# /var/folders/cz/0wfwkq6s5k1c7m5_4xbzy9z00000gn/T/ipykernel_3343/2945578198.py in convert(s)
#      16     number = ''
#      17     for token in s:
# ---> 18         number += DIGIT_MAP[token]
#      19     x = int(number)
#      20     return x
#
# KeyError: 'grax'

# %%
DIGIT_MAP = {
    'zero':  '0',
    'one':   '1',
    'two':   '2',
    'three': '3',
    'four':  '4',
    'five':  '5',
    'six':   '6',
    'seven': '7',
    'eight': '8',
    'nine':  '9',
}


def convert(s):
    """Convert a string to an integer."""
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
        print(f"Conversion succeeded! x = {x}")
    except KeyError:
        print("Conversion failed!")
        x = -1
    except TypeError:
        print("Conversion failed!")
        x = -1
    return x

def convert_v2(s):
    """Convert a string to an integer."""
    x = -1
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
        print(f"Conversion succeeded! x = {x}")
    except (KeyError, TypeError):
        print("Conversion failed!")
    return x

convert1("one six seven".split())

convert1("one grax seven".split())

convert(512)
# Out:
# Conversion succeeded! x = 167
# Conversion failed!
# Conversion failed!
# -1

# %%
DIGIT_MAP = {
    'zero':  '0',
    'one':   '1',
    'two':   '2',
    'three': '3',
    'four':  '4',
    'five':  '5',
    'six':   '6',
    'seven': '7',
    'eight': '8',
    'nine':  '9',
}

def convert(s):
    """Convert a string to an integer."""
    x = -1
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
    except (KeyError, TypeError):
    return x

def convert2(s):
    """Convert a string to an integer."""
    x = -1
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        x = int(number)
    except (KeyError, TypeError):
        pass
    return x

def convert3(s):
    """Convert a string to an integer."""
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        return int(number)
    except (KeyError, TypeError):
        return -1

import sys

def convert4(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        return int(number)
    except (KeyError, TypeError) as e:
        print(f"Conversion error: {e!r}",
              file=sys.stderr)
        return -1


convert("one six seven".split())

convert("one grax seven".split())

convert(512)
# Out:
#   File "/var/folders/cz/0wfwkq6s5k1c7m5_4xbzy9z00000gn/T/ipykernel_1893/3328356381.py", line 23
#     return x
#     ^
# IndentationError: expected an indented block

# %%
from math import log
import sys

DIGIT_MAP = {
    'zero':  '0',
    'one':   '1',
    'two':   '2',
    'three': '3',
    'four':  '4',
    'five':  '5',
    'six':   '6',
    'seven': '7',
    'eight': '8',
    'nine':  '9',
}


def convert(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        return int(number)
    except (KeyError, TypeError) as e:
        print(f"Conversion error: {e!r}",
              file=sys.stderr)
        return -1

def convert2(s):
    try:
        number = ''
        for token in s:
            number += DIGIT_MAP[token]
        return int(number)
    except (KeyError, TypeError) as e:
        print(f"Conversion error: {e!r}",
              file=sys.stderr)
        raise 
    

def string_log(s):
    v = convert2(s)
    return log(v)


#string_log("six one seven".split())
string_log(522355)
# Out:
# Conversion error: TypeError("'int' object is not iterable")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/cz/0wfwkq6s5k1c7m5_4xbzy9z00000gn/T/ipykernel_3343/3113101325.py in <module>
#      45
#      46 #string_log("six one seven".split())
# ---> 47 string_log(522355)
#
# /var/folders/cz/0wfwkq6s5k1c7m5_4xbzy9z00000gn/T/ipykernel_3343/3113101325.py in string_log(s)
#      40
#      41 def string_log(s):
# ---> 42     v = convert2(s)
#      43     return log(v)
#      44
#
# /var/folders/cz/0wfwkq6s5k1c7m5_4xbzy9z00000gn/T/ipykernel_3343/3113101325.py in convert2(s)
#      30     try:
#      31         number = ''
# ---> 32         for token in s:
#      33             number += DIGIT_MAP[token]
#      34         return int(number)
#
# TypeError: 'int' object is not iterable
